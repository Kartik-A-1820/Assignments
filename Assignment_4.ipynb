# %% [markdown]
# # 1.1 Write a Python Program(with class concepts) to find the area of the triangle using the below  formula.
# area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
# Function to take the length of the sides of triangle from user should be defined in the parent  class and function to calculate the area should be defined in subclass.

# %%
class Triangle:
    def __init__(self):
        self.a = float(input("Enter side a: "))
        self.b = float(input("Enter side b: "))
        self.c = float(input("Enter side c: "))

# %%
class Area(Triangle):
    def area(self):
        s = (self.a + self.b + self.c) / 2
        area = (s * (s - self.a)*(s - self.b)*(s - self.c)) ** 0.5
        print('Area of the Triangle is = {} '.format(round(area,4)))

# %%
i = Area()
i.area()
# Out:
# Enter side a: 20
# Enter side b: 30
# Enter side c: 40
# Area of the Triangle is = 290.4738

# %% [markdown]
# # 1.2 Write a function filter_long_words() that takes a list of words and an integer n and returns  the list of words that are longer than n.

# %%
def filter_long_words(words, n):
    l = []
    for i in words:
        if len(i) > n:
            l.append(i)
    print(f"Longest words are: {l}")

# %%
lst = ["Lion","Elephant","Leopard","Tiger","Bear","Crocodile","Buffalo","Cow"]
n=input('Enter length to filter:')
filter_long_words(lst, int(n))
# Out:
# Enter length to filter:4
# Longest words are: ['Elephant', 'Leopard', 'Tiger', 'Crocodile', 'Buffalo']

# %% [markdown]
# # 2.1 Write a Python program using function concept that maps list of words into a list of integers  representing the lengths of the corresponding words.
# Hint: If a list [ ab,cde,erty] is passed on to the python function output should come as [2,3,4] Here 2,3 and 4 are the lengths of the words in the list.

# %%
def words_to_int(word):
    return len(word)

# %%
lst = ["Lion","Elephant","Leopard","Tiger","Bear","Crocodile","Buffalo","Cow"]

# %%
result = map(words_to_int,lst)

# %%
print(list(result))
# Out:
# [4, 8, 7, 5, 4, 9, 7, 3]

# %% [markdown]
# # 2.2 Write a Python function which takes a character (i.e. a string of length 1) and returns True if  it is a vowel, False otherwise.

# %%
def is_vowel(char):
    if char.lower() in ['a','e','i','o','u']:
        return True
    else:
        return False

# %%
n=input('Enter character:')
if len(n)==1:
    print(is_vowel(n))
else:
    print('Please enter a single Character')
# Out:
# Enter character:A
# True
